# %% [markdown]
# # Summary plot demo

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd "/app/"
# Out:
# /app
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %run env.py
# %run run.py connect
# Out:
# 2026-01-30 10:27:47,233::INFO::settings.py::Setting loglevel to INFO
# 2026-01-30 10:27:47,234::INFO::settings.py::Setting stores to {}
# 2026-01-30 10:27:47,234::INFO::settings.py::Setting database.misc.schema_prefix to
# 2026-01-30 10:27:47,235::INFO::settings.py::Setting database.misc.create_tables to True
# 2026-01-30 10:27:47,235::INFO::settings.py::Setting enable_python_native_blobs to True
# 2026-01-30 10:27:47,236::INFO::settings.py::Setting database.host to 128.178.51.167:3309
# 2026-01-30 10:27:47,236::INFO::settings.py::Setting database.user to celia
# 2026-01-30 10:27:47,237::INFO::settings.py::Setting database.password to celia
# 2026-01-30 10:27:47,270::INFO::connection.py::Connected celia@128.178.51.167:3309
# 2026-01-30 10:27:47,277::INFO::table.py::could not log event in table ~log
# Connecting celia@128.178.51.167:3309
# 2026-01-30 10:27:47,666::INFO::table.py::could not log event in table ~log
# 2026-01-30 10:27:47,666::INFO::table.py::could not log event in table ~log
# 2026-01-30 10:27:47,679::INFO::table.py::could not log event in table ~log
# 2026-01-30 10:27:47,679::INFO::table.py::could not log event in table ~log
# 2026-01-30 10:27:47,705::INFO::table.py::could not log event in table ~log
# 2026-01-30 10:27:47,705::INFO::table.py::could not log event in table ~log
# 2026-01-30 10:27:47,731::INFO::table.py::could not log event in table ~log
# 2026-01-30 10:27:47,731::INFO::table.py::could not log event in table ~log

# %%
from vr4mice.analysis.summary_dj import vr4mice_summary_plots
from run import create_folder_if_not_exist

# %%
key = {"dataset": "Hamster_2026-01-26_1"}

# %%
save_path = "."
create_folder_if_not_exist(save_path)
vr4mice_summary_plots(key=key, save_path=save_path, database=True)
# Out:
# 2026-01-30 10:27:47,896::INFO::run.py::Folder '.' already exists.
# 2026-01-30 10:27:47,896::INFO::run.py::Folder '.' already exists.
# 2026-01-30 10:27:47,979::INFO::summary_dj.py::Trying to get data from database...
# 2026-01-30 10:27:47,979::INFO::summary_dj.py::Trying to get data from database...
# 2026-01-30 10:29:03,819::INFO::summary_dj.py::Data fetched for {'dataset': 'Hamster_2026-01-26_1'}
# 2026-01-30 10:29:03,819::INFO::summary_dj.py::Data fetched for {'dataset': 'Hamster_2026-01-26_1'}
# 2026-01-30 10:29:03,821::INFO::summary_dj.py::Add trial rewarded...
# 2026-01-30 10:29:03,821::INFO::summary_dj.py::Add trial rewarded...
# 2026-01-30 10:29:09,818::INFO::summary_dj.py::Box data fetched for {'dataset': 'Hamster_2026-01-26_1'}
# 2026-01-30 10:29:09,818::INFO::summary_dj.py::Box data fetched for {'dataset': 'Hamster_2026-01-26_1'}
# 2026-01-30 10:29:11,861::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,861::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,867::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,867::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,882::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,882::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,893::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,893::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,917::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,917::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,927::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:11,927::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,086::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,086::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,093::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,093::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,116::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,116::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,122::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,122::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,137::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,137::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,146::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,146::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,302::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,302::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,309::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,309::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,331::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,331::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,344::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,344::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,374::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,374::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,385::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-01-30 10:29:12,385::INFO::category.py::Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# PosixPath('Hamster_2026-01-26_1_summary_plot.png')

# %%
from IPython.display import Image, display

image_path = save_path + "/" + key["dataset"] + "_summary_plot.png"
display(Image(filename=image_path))
