# %% [markdown]
# # Summary plot demo

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd "/app/"
# Out:
# /app
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %run env.py
# %run run.py connect
# Out:
# 2026-01-28 09:07:00,718::INFO::settings.py::Setting loglevel to INFO
# 2026-01-28 09:07:00,723::INFO::settings.py::Setting stores to {}
# 2026-01-28 09:07:00,727::INFO::settings.py::Setting database.misc.schema_prefix to
# 2026-01-28 09:07:00,731::INFO::settings.py::Setting database.misc.create_tables to True
# 2026-01-28 09:07:00,733::INFO::settings.py::Setting enable_python_native_blobs to True
# 2026-01-28 09:07:00,734::INFO::settings.py::Setting database.host to 128.178.51.167:3309
# 2026-01-28 09:07:00,735::INFO::settings.py::Setting database.user to celia
# 2026-01-28 09:07:00,736::INFO::settings.py::Setting database.password to celia
# 2026-01-28 09:07:00,798::INFO::connection.py::Connected celia@128.178.51.167:3309
# 2026-01-28 09:07:00,811::INFO::table.py::could not log event in table ~log
# Connecting celia@128.178.51.167:3309
# 2026-01-28 09:07:01,466::INFO::table.py::could not log event in table ~log
# ...

# %%
from vr4mice.analysis.summary_dj import vr4mice_summary_plots
from run import create_folder_if_not_exist

# %%
key = {"dataset": "Hamster_2026-01-26_1"}

# %%
save_path = "."
create_folder_if_not_exist(save_path)
vr4mice_summary_plots(key=key, save_path=save_path, database=True)
# Out:
# 2026-01-28 09:07:01,924::INFO::run.py::Folder '.' already exists.
# 2026-01-28 09:07:01,924::INFO::run.py::Folder '.' already exists.
# 2026-01-28 09:07:02,064::INFO::summary_dj.py::Trying to get data from database...
# 2026-01-28 09:07:02,064::INFO::summary_dj.py::Trying to get data from database...
# 2026-01-28 09:08:57,607::INFO::summary_dj.py::Data fetched for {'dataset': 'Hamster_2026-01-26_1'}
# 2026-01-28 09:08:57,607::INFO::summary_dj.py::Data fetched for {'dataset': 'Hamster_2026-01-26_1'}
# 2026-01-28 09:08:57,612::INFO::summary_dj.py::Add trial rewarded...
# 2026-01-28 09:08:57,612::INFO::summary_dj.py::Add trial rewarded...
# 2026-01-28 09:09:06,965::INFO::summary_dj.py::Box data fetched for {'dataset': 'Hamster_2026-01-26_1'}
# 2026-01-28 09:09:06,965::INFO::summary_dj.py::Box data fetched for {'dataset': 'Hamster_2026-01-26_1'}
# ...

# %%
from IPython.display import Image, display

image_path = save_path + "/" + key["dataset"] + "_summary_plot.png"
display(Image(filename=image_path))
